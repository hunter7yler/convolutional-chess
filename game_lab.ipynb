# %%
from chessmate.simulations import ChessPlayground
from chessmate.engines import CaptureHighestValue
from chessmate.utils import display_all_results
from local_engines import HighestValue_OR_NN
nn = HighestValue_OR_NN()
hv = CaptureHighestValue()
simulation = ChessPlayground(nn, hv)
simulation.play_multiple_games(1000)
display_all_results(simulation.all_results)
# Out:
# Playing game 187:  19%|█▊        | 186/1000 [02:32<11:05,  1.22it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-dff2c0b3a38e> in <module>
#       6 hv = CaptureHighestValue()
#       7 simulation = ChessPlayground(nn, hv)
# ----> 8 simulation.play_multiple_games(1000)
#       9 display_all_results(simulation.all_results)
#      10
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/chessmate/simulations.py in play_multiple_games(self, N)
#     362         for game_number in progress_bar:
#     363             progress_bar.set_description(f"Playing game {game_number}")
# --> 364             self.play_game()
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/chessmate/simulations.py in play_game(self)
#     320         while not self._board.is_game_over():
#     321             # If white ends game on move, don't execute black move
# --> 322             white_move = self.white_engine.move(self._board)
#     323             if white_move == chess.Move.null():
#     324                 break
#
# ~/Dev/Projects/nn_chess/local_engines.py in move(self, board)
#      78         """Select move that features capture out of random moves
#      79         if one is available. See parent docstring"""
# ---> 80         self.evaluate(board)
#      81
#      82         if not [*self.legal_moves]:
#
# ~/Dev/Projects/nn_chess/local_engines.py in evaluate(self, board)
#      57         bint = np.ndarray(shape=(1, 8, 8, 12))
#      58         bint[0] = board_convert(str(board))
# ---> 59         s_array, e_array = self.start_nn(bint).numpy()[0], self.end_nn(bint).numpy()[0]
#      60
#      61         legal_move_list = list(board.legal_moves)
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     996         inputs = self._maybe_cast_inputs(inputs, input_list)
#     997
# --> 998       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     999       if eager:
#    1000         call_fn = self.call
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in input_spec(self)
#     502     if hasattr(self, '_manual_input_spec'):
#     503       return self._manual_input_spec
# --> 504     if self.layers and hasattr(self.layers[0], 'input_spec'):
#     505       return self.layers[0].input_spec
#     506     return None
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py in layers(self)
#     151     # `Trackable` manages the `_layers` attributes and does filtering
#     152     # over it.
# --> 153     layers = super(Sequential, self).layers
#     154     if layers and isinstance(layers[0], input_layer.InputLayer):
#     155       return layers[1:]
#
# ~/Dev/Projects/nn_chess/nnc_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in layers(self)
#    2386   @property
#    2387   def layers(self):
# -> 2388     return list(self._flatten_layers(include_self=False, recursive=False))
#    2389
#    2390   def get_layer(self, name=None, index=None):
#
# KeyboardInterrupt:

# %%
from chessmate.simulations import ChessPlayground
from chessmate.engines import MiniMax
from chessmate.utils import display_all_results
from local_heuristics import NNP

mmn = MiniMax(color=True, depth=2)
mmn.ordering_heuristic = NNP
mmr = MiniMax(color=False, depth=2)
mmr.move_ordering = False

simulation = ChessPlayground(mmn, mmr)
simulation.play_multiple_games(10)

display_all_results(simulation.all_results)
# Out:
# Playing game 10: 100%|██████████| 10/10 [03:11<00:00, 19.11s/it]
# Counter({'Insufficient material': 1,
#          'Stalemate': 2,
#          'Fivefold repetition': 2,
#          'Black win by mate': 2,
#          'White win by mate': 3})
